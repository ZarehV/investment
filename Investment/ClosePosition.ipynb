# %%
from common.journal import get_journal, get_position, close_position

close_position()
# Out:
# Which is the position id to close Oyrl7/gE3qv/+sULVWxNLvH8q/7U464p5gm4i2J29Dk=
# *****RECORD*****
# {
#  "symbol": "IJR",
#  "purchase_price": 117.07,
#  "position_size": 400,
#  "investment_account": "TradeStation Simulation",
#  "investment_reason": "Momentum was identified started since 07/10/2024",
#  "stop_loss": 115.5,
#  "target_risk_reward_ratio": 2.0,
#  "purchase_date": "2024-07-17",
#  "status": "open",
#  "actual_profit_lost": 0.0,
#  "actual_profit_lost_pct": 0.0,
#  "exit_comments": " ",
#  "take_profit": NaN,
#  "earnings_target": NaN,
#  "earning_target_pct": NaN,
#  "loss_target": NaN,
#  "loss_target_pct": NaN,
#  "final_filled_price": NaN,
#  "final_PL": NaN,
#  "final_pct_revenue": NaN,
#  "closing_date": NaN,
#  "key": "Oyrl7/gE3qv/+sULVWxNLvH8q/7U464p5gm4i2J29Dk=",
#  "investment_type": "Long",
#  "target_take_profit": 120.20999999999998,
#  "target_profit": 1255.9999999999927,
#  "target_profit_pct": 0.0268215597505764,
#  "target_loss": -628.0,
# ...
