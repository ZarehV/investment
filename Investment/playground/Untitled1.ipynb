# %%
import requests


URL = "https://elite.finviz.com/export.ashx?v=111&f=sh_avgvol_o500,sh_opt_optionshort,sh_price_5to50,sh_relvol_o0.5,sh_short_u10,ta_perf_0.5to-i30,ta_perf2_to2-d,ta_rsi_50to70,ta_sma200_pa&o=-volume&auth=ac6ca4f5-a2dd-43f2-b3ef-813d46627860"

response = requests.get(URL)

open("export.csv", "wb").write(response.content)
# Out:
# 991

# %%
import pandas as pd
from io import StringIO


df = pd.read_csv(StringIO(response.text), sep=",")
df.index = df["Ticker"]

# %%
df
# Out:
#         No. Ticker                          Company                  Sector  \
# Ticker
# JMIA      1   JMIA        Jumia Technologies Ag ADR       Consumer Cyclical
# DO        2     DO  Diamond Offshore Drilling, Inc.                  Energy
# MAT       3    MAT                     Mattel, Inc.       Consumer Cyclical
# GENI      4   GENI            Genius Sports Limited  Communication Services
# NE        5     NE                   Noble Corp Plc                  Energy
# ALHC      6   ALHC         Alignment Healthcare Inc              Healthcare
# MWA       7    MWA       Mueller Water Products Inc             Industrials
# BV        8     BV          BrightView Holdings Inc             Industrials
#
#                               Industry         Country  Market Cap    P/E  \
# Ticker
# JMIA                   Internet Retail         Germany     1247.06    NaN
# DO                  Oil & Gas Drilling             USA     1699.12    NaN
# ...
