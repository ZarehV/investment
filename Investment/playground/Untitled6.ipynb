# %%
import yfinance as yf

# %%
ticker = "IJR"
data = yf.download(ticker, period="1y", interval="1d")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
from ..common.strategies import ScalpingVWAPRSI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ..common.strategies import ScalpingVWAPRSI
#
# ImportError: attempted relative import with no known parent package

# %%
strategy = ScalpingVWAPRSI(data, "Adj Close", True)
data = strategy.get_indicators()
data = strategy.get_signals(rsi_buy_signal=80, rsi_sell_signal=30)
strategy.backtest()
